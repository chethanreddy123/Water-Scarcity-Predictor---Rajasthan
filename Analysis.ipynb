# %%
# importing the required modules
import glob
import pandas as pd

# specifying the path to csv files
path = "DataSet"

# csv files in the path
file_list = glob.glob(path + "/*.xlsx")

# list of excel files we want to merge.
# pd.read_excel(file_path) reads the excel
# data into pandas dataframe.
excl_list = []

for file in file_list:
	excl_list.append(pd.read_excel(file))

# create a new dataframe to store the
# merged excel file.
excl_merged = pd.DataFrame()

for excl_file in excl_list:
	
	# appends the data into the excl_merged
	# dataframe.
	excl_merged = excl_merged.append(
	excl_file, ignore_index=True)

# exports the dataframe into excel file with
# specified name.
excl_merged.to_excel('total_water.xlsx', index=False)
# Out:
# /var/folders/c2/x_cgj8b10s38q85qqx_c88hr0000gn/T/ipykernel_10557/509429117.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   excl_merged = excl_merged.append(

# %%
import pandas as pd

df = pd.read_excel(r'total_water.xlsx')
df
# Out:
#          SN  District          Block      Village Well Type   Hyd_Formation  \
# 0      6701     Sikar  Danta Ramgarh    Chirasara        PZ  Older Alluvium
# 1      6702     Sikar  Danta Ramgarh     Godiawas        PZ  Older Alluvium
# 2      6703     Sikar  Danta Ramgarh    Karanpura        PZ  Older Alluvium
# 3      6704     Sikar  Danta Ramgarh       Khatoo        PZ  Older Alluvium
# 4      6705     Sikar  Danta Ramgarh        Khood        PZ  Older Alluvium
# ...     ...       ...            ...          ...       ...             ...
# 76795  2151  Bhilwara         Raipur    Galyawari        DW          Gneiss
# 76796  2152  Bhilwara         Raipur       Jharol        DW          Gneiss
# 76797  2153  Bhilwara         Raipur       Jogras        DW          Gneiss
# 76798  2154  Bhilwara         Raipur  Kalal Kheri        PZ          Gneiss
# 76799  2155  Bhilwara         Raipur      Khemana        DW          Gneiss
#
# ...

# %%
myData = df.loc[df['District'] == 'Sikar']
myData
# Out:
#          SN District          Block        Village Well Type   Hyd_Formation  \
# 0      6701    Sikar  Danta Ramgarh      Chirasara        PZ  Older Alluvium
# 1      6702    Sikar  Danta Ramgarh       Godiawas        PZ  Older Alluvium
# 2      6703    Sikar  Danta Ramgarh      Karanpura        PZ  Older Alluvium
# 3      6704    Sikar  Danta Ramgarh         Khatoo        PZ  Older Alluvium
# 4      6705    Sikar  Danta Ramgarh          Khood        PZ  Older Alluvium
# ...     ...      ...            ...            ...       ...             ...
# 73651  7627    Sikar    Srimadhopur     Bhopatpura        PZ  Older Alluvium
# 73652  7628    Sikar    Srimadhopur  Jorawar Nagar        PZ  Older Alluvium
# 73653  7629    Sikar    Srimadhopur    Prithvipura        PZ  Older Alluvium
# 73654  7630    Sikar    Srimadhopur    Srimadhopur        PZ  Older Alluvium
# 73655  7631    Sikar    Srimadhopur  Kotri Simarla        PZ  Older Alluvium
#
# ...

# %%
myData = df.loc[df['District'] == 'Bhilwara']
myData
# Out:
#          SN  District   Block      Village Well Type Hyd_Formation  Year  \
# 2715   1644  Bhilwara   Asind     Akarsada        DW        Schist  2012
# 2716   1645  Bhilwara   Asind     Akarsada        PZ        Schist  2012
# 2717   1646  Bhilwara   Asind       Antali        DW        Schist  2012
# 2718   1647  Bhilwara   Asind       Antali        PZ        Gneiss  2012
# 2719   1648  Bhilwara   Asind       Badnor        DW        Gneiss  2012
# ...     ...       ...     ...          ...       ...           ...   ...
# 76795  2151  Bhilwara  Raipur    Galyawari        DW        Gneiss  2020
# 76796  2152  Bhilwara  Raipur       Jharol        DW        Gneiss  2020
# 76797  2153  Bhilwara  Raipur       Jogras        DW        Gneiss  2020
# 76798  2154  Bhilwara  Raipur  Kalal Kheri        PZ        Gneiss  2020
# 76799  2155  Bhilwara  Raipur      Khemana        DW        Gneiss  2020
#
#       Total_Depth (M) WL PREMONSOON WL POSTMONSOON FLUCTUATION
# ...

# %%
myData = df.loc[df['District'] == 'Udaipur']
myData
# Out:
#          SN District    Block          Village Well Type    Hyd_Formation  \
# 710    7411  Udaipur  Badgaon           Amberi        DW         Phyllite
# 711    7412  Udaipur  Badgaon          Badgaon        DW         Phyllite
# 712    7413  Udaipur  Badgaon          Badgaon        PZ         Phyllite
# 713    7414  Udaipur  Badgaon             Bari        DW           Gneiss
# 714    7415  Udaipur  Badgaon             Bari        PZ           Gneiss
# ...     ...      ...      ...              ...       ...              ...
# 74640  8616  Udaipur   Semari       Bana Khurd        DW           Gneiss
# 74641  8617  Udaipur   Semari  Soorkhand Khera        DW           Gneiss
# 74642  8618  Udaipur   Semari          Sallara        DW  Phyllite/Schist
# 74643  8619  Udaipur   Semari         Veerpura        DW           Gneiss
# 74644  8620  Udaipur   Semari         Veerpura        PZ           Gneiss
#
#        Year Total_Depth (M)        WL PREMONSOON WL POSTMONSOON FLUCTUATION
# ...

# %%
myData = df.loc[df['District'] == 'Udaipur']
myData = myData.loc[df['Block'] == 'Semari']
myData
# Out:
#          SN District   Block          Village Well Type    Hyd_Formation  \
# 1057   7758  Udaipur  Semari            Kunda        DW  Phyllite/Schist
# 1058   7759  Udaipur  Semari            Kunda        PZ  Phyllite/Schist
# 1059   7760  Udaipur  Semari           Semari        DW  Phyllite/Schist
# 1060   7761  Udaipur  Semari           Semari        PZ  Phyllite/Schist
# 1061   7762  Udaipur  Semari           Bhorai        DW  Phyllite/Schist
# ...     ...      ...     ...              ...       ...              ...
# 74640  8616  Udaipur  Semari       Bana Khurd        DW           Gneiss
# 74641  8617  Udaipur  Semari  Soorkhand Khera        DW           Gneiss
# 74642  8618  Udaipur  Semari          Sallara        DW  Phyllite/Schist
# 74643  8619  Udaipur  Semari         Veerpura        DW           Gneiss
# 74644  8620  Udaipur  Semari         Veerpura        PZ           Gneiss
#
#        Year Total_Depth (M)        WL PREMONSOON WL POSTMONSOON FLUCTUATION
# ...

# %%
myData = df.loc[df['District'] == 'Sikar']
myData = myData.loc[df['Block'] == 'Danta Ramgarh']
myData = myData.loc[df['Village'] == 'Chirasara']

myData = myData.loc[df['Well Type'] == 'PZ']
# myData = myData.sort_values(by=['Year'])
myData
# Out:
#          SN District          Block    Village Well Type   Hyd_Formation  \
# 0      6701    Sikar  Danta Ramgarh  Chirasara        PZ  Older Alluvium
# 11961  7417    Sikar  Danta Ramgarh  Chirasara        PZ  Older Alluvium
# 20987  6701    Sikar  Danta Ramgarh  Chirasara        PZ  Older Alluvium
# 33063  6706    Sikar  Danta Ramgarh  Chirasara        PZ  Older Alluvium
# 37290  6701    Sikar  Danta Ramgarh  Chirasara        PZ  Older Alluvium
# 51752  6701    Sikar  Danta Ramgarh  Chirasara        PZ  Older Alluvium
# 59524  6701    Sikar  Danta Ramgarh  Chirasara        PZ  Older Alluvium
# 62227  7200    Sikar  Danta Ramgarh  Chirasara        PZ  Older Alluvium
# 73456  7432    Sikar  Danta Ramgarh  Chirasara        PZ  Older Alluvium
#
#        Year Total_Depth (M) WL PREMONSOON WL POSTMONSOON FLUCTUATION
# 0      2011            85.8         59.05          60.19       -1.14
# 11961  2020            85.8          75.4          75.63       -0.23
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

x = list(np.array(myData['Year']))
y = list(np.array(myData['WL PREMONSOON']))

print(x,y)
# Out:
# [2011, 2012, 2014, 2015, 2016, 2017, 2018, 2019, 2020] [7.11, 4.82, 4.92, 6.58, 7.72, 6.1, 1.8, 7.5, 5.8]

# %%
print(len(x),len(y))
# Out:
# 9 9

# %%
type(y[0])
# Out:
# float

# %%
import numpy
import matplotlib.pyplot as plt

mymodel = numpy.poly1d(numpy.polyfit(x, y, 3))

myline = [2021, 2022, 2023]

plt.scatter(x, y)
plt.plot(x,y)
plt.plot(x + [2021],  mymodel(x + [2021]))
plt.plot(myline, mymodel(myline))
plt.show()

# %%
myline = np.array([2022, 2023, 2024])

plt.scatter(x, y)
plt.plot(myline, mymodel(myline))
plt.show()

# %%
pip install geopy
# Out:
# ...
#   Using cached geopy-2.3.0-py3-none-any.whl (119 kB)
# ...
#   Using cached geographiclib-2.0-py3-none-any.whl (40 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from geopy.geocoders import Nominatim

# Initialize Nominatim API
geolocator = Nominatim(user_agent="MyApp")

location = geolocator.geocode("Rajasthan")

print("The latitude of the location is: ", location.latitude)
print("The longitude of the location is: ", location.longitude)
# Out:
# The latitude of the location is:  26.8105777
# The longitude of the location is:  73.7684549

# %%
myData = myData.sort_values(by=['Hyd_Formation'])
myData
# Out:
#          SN District   Block Village Well Type    Hyd_Formation  Year  \
# 1057   7758  Udaipur  Semari   Kunda        DW  Phyllite/Schist  2011
# 22044  7758  Udaipur  Semari   Kunda        DW  Phyllite/Schist  2012
# 38347  7758  Udaipur  Semari   Kunda        DW  Phyllite/Schist  2014
# 52809  7758  Udaipur  Semari   Kunda        DW  Phyllite/Schist  2015
# 60581  7758  Udaipur  Semari   Kunda        DW  Phyllite/Schist  2016
# 41624  7763  Udaipur  Semari   Kunda        DW  Phyllite/Schist  2017
# 63356  8329  Udaipur  Semari   Kunda        DW  Phyllite/Schist  2018
# 74630  8606  Udaipur  Semari   Kunda        DW  Phyllite/Schist  2019
# 13135  8591  Udaipur  Semari   Kunda        DW  Phyllite/Schist  2020
#
#       Total_Depth (M) WL PREMONSOON WL POSTMONSOON FLUCTUATION
# 1057               11          7.11            1.6        5.51
# 22044              11          4.82            1.8        3.02
# 38347              11          4.92           2.72         2.2
# ...

# %%
myData.Village.unique()
# Out:
# array(['Kunda'], dtype=object)

# %%
myData = df.loc[df['District'] == 'Sikar']
myData = myData.loc[df['Block'] == 'Danta Ramgarh']


myData.Village.unique()
# Out:
# array(['Chirasara', 'Godiawas', 'Karanpura', 'Khatoo', 'Khood',
#        'Motlawas', 'Lamiyan', 'Pachar', 'Karad', 'Sulyawas', 'Losal',
#        'Rajpura', 'Aloda', 'Doodwa', 'Dookiya', 'Gowati', 'Jeen Mata',
#        'Neemera', 'Roopgarh', 'Tehat', 'Danta', 'Ramgarh', 'Anantpura',
#        'Kankra', 'Mandha Surera', 'Surera', 'Mandha', 'Bay', 'Bhagatpura'],
#       dtype=object)

# %%
def Clean(L):
    New_L = []
    
    for i in L:
        if type(i) == int or type(i) == float:
            New_L.append(i)
            
    return New_L




def DepthCal(Df):
    AveragePre = sum( Clean(list(Df['WL PREMONSOON']))) / len(Df['WL PREMONSOON'])
    AveragePos = sum( Clean(list(Df['WL POSTMONSOON']))) / len(Df['WL POSTMONSOON'])
    AverageFlu = sum( Clean(list(Df['FLUCTUATION']))) / len(Df['FLUCTUATION'])
     
    Total = AverageFlu+AveragePos+AveragePre
    
    return Total

def AllCal(Df):
    ListVillage = list(Df.Village.unique())
    
    FinalList = []
    
    for i in ListVillage:
        newDf = Df.loc[Df['Village'] == i]
        # print(newDf)
        FinalList.append((i, DepthCal(newDf)))
    
    max_tuple = max(FinalList, key=lambda tup: tup[1])
    
    return max_tuple

# %%
AllCal(myData)
# Out:
# ('Bhagatpura', 147.66666666666666)

# %%
AveragePre = sum( list(myData['WL PREMONSOON']) ) / len(myData['WL PREMONSOON'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 AveragePre = sum( list(myData['WL PREMONSOON']) ) / len(myData['WL PREMONSOON'])
#
# TypeError: unsupported operand type(s) for +: 'float' and 'str'

# %%
Clean(list(myData['WL PREMONSOON']))
# Out:
# [59.05,
#  62.38,
#  65.84,
#  16.65,
#  69.43,
#  36.5,
#  47.6,
#  17.4,
#  36.38,
#  25.18,
#  14,
#  53.35,
#  54.7,
#  39.3,
#  83.1,
#  75.4,
#  73.67,
#  48.97,
#  72.22,
#  51.31,
#  69.73,
#  89.28,
#  43.18,
#  14.18,
#  36.96,
#  25.96,
#  52.92,
#  66.52,
#  33.05,
#  40.1,
#  32.34,
#  46.7,
#  48.3,
#  44.9,
#  39.77,
#  23.25,
#  66.55,
#  62.08,
#  64.13,
#  66.9,
#  17.78,
#  72.64,
#  38.96,
#  48.34,
#  17.55,
#  37,
#  26.26,
#  14.1,
#  54.25,
#  55,
#  36.46,
#  49.45,
#  41.75,
#  28.48,
#  75.75,
#  70.35,
#  70.28,
#  43.47,
#  67.38,
#  62.21,
#  49.35,
#  88.05,
#  65.35,
#  83.1,
#  33.32,
#  49.88,
#  14.92,
#  32.34,
#  25.7,
#  54.78,
#  55.48,
#  66.68,
#  30.65,
#  40.1,
#  29.8,
#  43.5,
#  48.8,
#  41.7,
#  41.55,
#  25.95,
#  69.1,
#  65.68,
#  66,
#  68.9,
#  19.95,
#  74.36,
#  41.8,
#  63.65,
#  53.55,
#  48.8,
#  81.87,
#  61.98,
#  48.43,
#  15.62,
#  36.02,
#  25.11,
#  13.68,
#  53.98,
#  55.82,
#  65.9,
#  28.33,
#  39.65,
#  28.88,
# ...

# %%
int == type(1)
# Out:
# True

# %%
sum(Clean(list(myData['WL PREMONSOON']))) / len(myData['WL PREMONSOON'])
# Out:
# 37.666259259259256

# %%
Clean(list(myData['WL PREMONSOON']))
